# %%
import numpy as np
import pandas as pd

import geopandas as gpd
from shapely.geometry import Point
from shapely.ops import nearest_points

import seaborn as sns
import matplotlib as mpl
import matplotlib.pyplot as plt

import os
import warnings
#import unicodedata
warnings.filterwarnings("ignore")
#from io import BytesIO
#import gzip
import requests

pd.set_option('display.max_rows',999)

# %%
pd.set_option('display.float_format', lambda x: '%.3f' % x)

# %%
ejd = pd.read_excel('files/analisis_ejd.xlsx',  sheet_name='Sheet1 (2)')

# %%
ejd.rename(columns={'Pais': 'Country' , 'Ciudad':'City'},inplace=True)
ejd.set_index(['Country' , 'City'],inplace=True)

# %%
ejd.head()
# Out:
#                                       principal_sector       HH  \
# Country City
# ARG     Bahia Blanca-Cerri                          s9 1588.577
#         Ciudad de Buenos Aires                      s9 1793.556
#         Comodoro Rivadavia-Rada Tilly               s1 1376.674
#         Concordia                                   s9 1766.705
#         Corrientes                                  s9 1853.123
#
#                                        principal_sector_share  HH_pais  \
# Country City
# ARG     Bahia Blanca-Cerri                              0.281 1560.071
#         Ciudad de Buenos Aires                          0.301 1560.071
#         Comodoro Rivadavia-Rada Tilly                   0.207 1560.071
#         Concordia                                       0.325 1560.071
#         Corrientes                                      0.329 1560.071
#
#                                        esp_HH  country_principal_sector_share  \
# Country City
# ARG     Bahia Blanca-Cerri              1.018                           0.277
#         Ciudad de Buenos Aires          1.150                           0.277
#         Comodoro Rivadavia-Rada Tilly   0.882                           0.029
#         Concordia                       1.132                           0.277
#         Corrientes                      1.188                           0.277
#
#                                        principal_sector_country_comparison  \
# Country City
# ARG     Bahia Blanca-Cerri                                           1.015
#         Ciudad de Buenos Aires                                       1.088
#         Comodoro Rivadavia-Rada Tilly                                7.024
#         Concordia                                                    1.173
#         Corrientes                                                   1.189
#
#                                        nivedu1  nivedu2  nivedu3  mujer  \
# Country City
# ARG     Bahia Blanca-Cerri               0.275    0.389    0.336  0.421
#         Ciudad de Buenos Aires           0.105    0.365    0.530  0.474
#         Comodoro Rivadavia-Rada Tilly    0.246    0.499    0.255  0.382
#         Concordia                        0.358    0.406    0.236  0.389
#         Corrientes                       0.220    0.425    0.355  0.427
#
#                                        hombre  formal  informal
# Country City
# ARG     Bahia Blanca-Cerri              0.579   0.564     0.436
#         Ciudad de Buenos Aires          0.526   0.714     0.286
#         Comodoro Rivadavia-Rada Tilly   0.618   0.731     0.269
#         Concordia                       0.611   0.594     0.406
#         Corrientes                      0.573   0.606     0.394

# %%
sel = ejd.iloc[:,:7]

# %%
sel.to_csv('Entregables/metricas/aglomerados.csv')
